# %% [markdown]
# ### **DIABETES DATASET IS DONE BECAUSE HAS MANY ROWS FOR ML**
# ### **TYPHOID DATASET IS ALSO DONE**

# %%
import pandas as pd
df=pd.read_csv("diabetes_prediction_dataset.csv")
df.shape
# Out:
# (100000, 9)

# %%
df2=pd.read_csv("Medicaldataset.csv")
df2.shape
# Out:
# (1319, 9)

# %%
df2=pd.read_csv("Typhoid_dataset.csv")
df2
# Out:
# (31087, 23)
